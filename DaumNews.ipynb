# %%
from bs4 import BeautifulSoup
import urllib.request as req

newsfile = open("news.txt", "w")

url = "https://news.daum.net/"
result = req.urlopen(url)
soup = BeautifulSoup(result, "html.parser")

news = soup.select("strong.tit_g")

for list in news :
    a = list.select_one("a")
    # print('링크 :' +
    newsfile.write("링크 :" + a.get('href') +'\n')

    title = a.string
    print('제목 :' + title)
    newsfile.write('제목 :' + title + "\n")

newsfile.close()
# Out:
# 제목 :
#                                     이재명 "尹, RE100 모르다니 상상하기 어려워"
#
# 제목 :
#                                     다시 고개 숙인 이재명, 김혜경 논란에 "면목 없다..다 제 불찰"
#
# 제목 :
#                                     펜 절도 오해해 초등생 옷 수색한 서점 주인 국민참여재판서 무죄
#
# 제목 :
#                                     '박사방' 조주빈, 옥중 블로그 운영 논란..네이버 "차단 방침"
#
# 제목 :
#                                     이재명 "국가경제 설계해야 하는데 RE100 모른다? 상상 어렵다"
#
# 제목 :
#                                     "곽상도 코로나 확진" 거짓 글 쓴 시사평론가 무죄 왜?
#
# 제목 :
#                                     광주 붕괴사고 24일 만에 5번째 매몰자 위치 확인
#
# 제목 :
#                                     美 "일본·호주와 연합 공중훈련..北 군사행동 저지 목적"
#
# 제목 :
#                                     '반도체 공급난' 기아, 1월 판매 21만2819대..전년比 5.7% 감소
#
# 제목 :
#                                     "검사 신속하게"..선별진료소 전자문진표 25→14개 간소화
#
# 제목 :
#                                     안철수 "임기 내 중소벤처 50조 공급..강소기업 상속세 대폭 감면"
#
# 제목 :
#                                     이대서울병원, 코로나 환자 전담치료 병동 열었다
#
# 제목 :
#                                     "김혜경 수행비서 채용은 가짜뉴스라더니..이재명, 페북 글 지웠다"
#
# 제목 :
#                                     "자가격리자 거소투표는 위법"..시민단체, 선관위 상대 행정소송
#
# 제목 :
#                                     코로나 '계절독감 전환' 검토..안정되면 '일상회복' 재추진
#
# 제목 :
#                                     8일 기자협회 주재 4자 TV토론 추진..민주 "참여하겠다"
#
# 제목 :
#                                     정부 "우크라 사태 직접 영향 제한적..장기화땐 부정적"
#
# 제목 :
#                                     심상정 "김혜경 의전, 상식적이지 않아..철저히 수사해야"
#
# 제목 :
#                                     어느날 그들의 노동이 사라진다면[플랫]
#
# 제목 :
#                                     美 국무부 "北 탄도미사일발사 규탄"..한미일 협력 강조
#
# 제목 :
#                                     "기후위기 대응 64개국 중 59위..우물 안 K-대통령 돼선 안 돼"
#
# 제목 :
#                                     [친절한 경제] 대체육이 고기 '대체'할 수 있을까?..MZ들이 주는 힌트
#
# 제목 :
#                                     어느날 그들의 노동이 사라진다면[플랫]
#
# 제목 :
#                                     금감원 지원금 100억 삭감..한국은행의 반격 시작됐다 [김익환의 BOK워치]
#
# 제목 :
#                                     우주복 입은 판다?..中 올림픽 마스코트 '빙둔둔' 인기 폭발
#
# 제목 :
#                                     운명처럼..눈보라 헤치며 시간과 싸운다 [김창길의 사진공책]
#
# 제목 :
#                                     서두르지 마세요..반려동물의 '마지막 소풍' 배웅하는 법
#
# 제목 :
#                                     당신은 몰라도, 대선 후보는 알아야 할 RE100과 택소노미
#
# 제목 :'우리동네공약' 이재명, "수도권 사드설치..주민삶 보탬 안돼"
# 제목 :'국순당' 52주 신고가 경신, 비 내리는 시장에 막걸리 한잔
# 제목 :'6명 모임·9시 제한' 2주 연장
# 제목 : 해운대의 노을
